# %% [markdown]
# <a href="https://colab.research.google.com/github/urmzd/lepus-classifier/blob/main/notebooks/experiment_0_k_fold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/*
# !git clone https://github.com/urmzd/lepus-classifier
# Out:
# Cloning into 'lepus-classifier'...
# remote: Enumerating objects: 1465, done.
# remote: Counting objects: 100% (1465/1465), done.
# remote: Compressing objects: 100% (925/925), done.
# remote: Total 1465 (delta 848), reused 966 (delta 433), pack-reused 0
# Receiving objects: 100% (1465/1465), 60.55 MiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (848/848), done.

# %%
# !pip install wandb pytorch-lightning pipetools loguru -q 
# !pip install pyyaml==5.4.1 -q

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: csci-4155-rabbit-classifier (use `wandb login --relogin` to force relogin)

# %%
import sys
SRC_PATH = "/content/lepus-classifier"
sys.path.insert(0, SRC_PATH)

# %%
from src.bootstrap import bootstrap, TrainerFactory, N_CLASSES
from src.data.data_handler import BasicModel, MetricsCallback
from pathlib import Path
import torch
import torch.nn.functional as F

trainer_factory = TrainerFactory(
    strategy=None, 
    max_epochs=16, 
)

for n_folds in range(1, 6):
  bootstrap(
      trainer_factory=trainer_factory,
      data_manifest_path=Path("/content/lepus-classifier/resources/data.csv"),
      model=BasicModel(),
      logger_kwargs={
          "name": f"K-Fold/{n_folds}"
      },
      num_folds= n_folds
  )
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# Global seed set to 42
# wandb: Currently logged in as: csci-4155-rabbit-classifier (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.14
# Run data is saved locally in <code>/content/wandb/run-20220410_080241-2mexpa44</code>
# Syncing run <strong><a href="https://wandb.ai/csci-4155-rabbit-classifier/rabbit-classifier/runs/2mexpa44" target="_blank">K-Fold/1</a></strong> to <a href="https://wandb.ai/csci-4155-rabbit-classifier/rabbit-classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
